# %% [markdown]
# # Explorador de peliculas buenas

# %%
import pandas as pd

# %%
# Install openpyxl if not already installed
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Usa una cadena raw para la ruta de Windows
excel_path = r"C:\Users\silvi\OneDrive - Universidad Pontificia Comillas\Documentos de interés\cosas mías\proyecto movie\data\peliculas.xlsx"

# Lee el archivo Excel
df = pd.read_excel(excel_path)
# Out:
#                                Nombre   Año              Género  Nota
# 0        Guess Who's Coming to Dinner  1967             Comedia   NaN
# 1                     What's Up, Doc?  1972             Comedia   NaN
# 2                      Trading Places  1983  Investment Banking   NaN
# 3                         Wall Street  1987  Investment Banking   NaN
# 4                 A Fish Called Wanda  1988             Comedia   NaN
# ..                                ...   ...                 ...   ...
# 113                       Glass Onion  2023             Intriga   NaN
# 114                         Novocaine  2025             Comedia   NaN
# 115               Expediente Warren 4  2025      Miedo/Thriller   NaN
# 116  Bridget Jones: Mad About the Boy  2025           Romántica   NaN
# 117   Downton Abbey: The Grand Finale  2025           Romántica   NaN
#
# [118 rows x 4 columns]
